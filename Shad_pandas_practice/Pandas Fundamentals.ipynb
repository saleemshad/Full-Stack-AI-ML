# %% [markdown]
# # Pandas Foundations

# %% [markdown]
# ## dissecting the anatomy of the data frame

# %%
import numpy as np
import pandas as pd

# %%
movie = pd.read_csv('data/movie.csv')

# %%
movie.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# ...

# %%
movie.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %% [markdown]
# ## Ascessing the main data frame components

# %%
columns = movie.columns

# %%
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
index = movie.index

# %%
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
data = movie.values

# %%
data
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
type(index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
type(columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(data)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Understanding Data Types

# %%
movie.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# ## Selecting the columns of data as a series

# %%
movie[['color', 'duration']]
# Out:
#       color  duration
# 0     Color     178.0
# 1     Color     169.0
# 2     Color     148.0
# 3     Color     164.0
# 4       NaN       NaN
# ...     ...       ...
# 4911  Color      87.0
# 4912  Color      43.0
# 4913  Color      76.0
# 4914  Color     100.0
# 4915  Color      90.0
#
# [4916 rows x 2 columns]

# %%
movie.director_name
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
type(movie['director_name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Displaying the data in a frame

# %%
director = movie['director_name']

# %%
director
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
director.to_frame()
# Out:
#           director_name
# 0         James Cameron
# 1        Gore Verbinski
# 2            Sam Mendes
# 3     Christopher Nolan
# 4           Doug Walker
# ...                 ...
# 4911        Scott Smith
# 4912                NaN
# 4913   Benjamin Roberds
# 4914        Daniel Hsia
# 4915           Jon Gunn
#
# [4916 rows x 1 columns]

# %% [markdown]
# ### Calling Series methods

# %%
s_attr_methods = set(dir(pd.Series))

# %%
s_attr_methods
# Out:
# {'T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
len(s_attr_methods) ## Total numbers of methods availble in pandas Series are:  421
# Out:
# 421

# %%
df_attr_methods = set(dir(pd.DataFrame))

# %%
df_attr_methods
# Out:
# {'T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
len(df_attr_methods) ## Total numbers of methods availble in pandas Series are:  432
# Out:
# 432

# %%
s_attr_methods & df_attr_methods
# Out:
# {'T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
len(s_attr_methods & df_attr_methods) # Total combinations of methods in both Series and DataFrame

# %%
director
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
actor_1_fb_likes = movie['actor_1_facebook_likes']

# %%
director.head()
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4          Doug Walker
# Name: director_name, dtype: object

# %%
actor_1_fb_likes.head()
# Out:
# 0     1000.0
# 1    40000.0
# 2    11000.0
# 3    27000.0
# 4      131.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
director.value_counts() 
#Returns a Series containing counts of unique values.
#The resulting object will be in descending order so that the first element is the most frequently-occurring element. 
#Excludes NA values by default.
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
# Ridley Scott        16
#                     ..
# John Putch           1
# Luca Guadagnino      1
# Sam Fell             1
# Dan Fogelman         1
# Daniel Hsia          1
# Name: director_name, Length: 2397, dtype: int64

# %%
director.value_counts().head() # getting the top 5 from the lists of unique occuring values

# %%
actor_1_fb_likes.value_counts() # 436 actor got 1000 fb likes
# Out:
# 1000.0     436
# 11000.0    206
# 2000.0     189
# 3000.0     150
# 12000.0    131
#           ...
# 703.0        1
# 208.0        1
# 79.0         1
# 269.0        1
# 291.0        1
# Name: actor_1_facebook_likes, Length: 877, dtype: int64

# %%
actor_1_fb_likes.value_counts().head()
# Out:
# 1000.0     436
# 11000.0    206
# 2000.0     189
# 3000.0     150
# 12000.0    131
# Name: actor_1_facebook_likes, dtype: int64

# %%
director.size 
# Return an int representing the number of elements in this object.
#Return the number of rows if Series. Otherwise return the number of rows times number of columns if DataFrame.
# Out:
# 4916

# %%
director.shape
#Return a tuple representing the dimensionality of the DataFrame.
# Out:
# (4916,)

# %%
len(director)

#Compute the length of each element in the Series/Index.
#The element may be a sequence (such as a string, tuple or list) or a collection (such as a dictionary).
# Out:
# 4916

# %%
director.count()
#Count non-NA cells for each column or row.
#The values None, NaN, NaT, and optionally numpy.
#inf (depending on pandas.options.mode.use_inf_as_na) are considered NA.
# Out:
# 4814

# %%
actor_1_fb_likes.count()
# Out:
# 4909

# %%
actor_1_fb_likes
# Out:
# 0        1000.0
# 1       40000.0
# 2       11000.0
# 3       27000.0
# 4         131.0
#          ...
# 4911      637.0
# 4912      841.0
# 4913        0.0
# 4914      946.0
# 4915       86.0
# Name: actor_1_facebook_likes, Length: 4916, dtype: float64

# %%
actor_1_fb_likes.min()
# Out:
# 0.0

# %%
actor_1_fb_likes.max()
# Out:
# 640000.0

# %%
actor_1_fb_likes.mean()
# Out:
# 6494.488490527602

# %%
actor_1_fb_likes.median()
# Out:
# 982.0

# %%
actor_1_fb_likes.std()
# Out:
# 15106.986883848309

# %%
actor_1_fb_likes.sum()
# Out:
# 31881444.0

# %%
actor_1_fb_likes.min(), actor_1_fb_likes.max(),\
actor_1_fb_likes.mean(),actor_1_fb_likes.median(),\
actor_1_fb_likes.std(),actor_1_fb_likes.sum()
# Out:
# (0.0, 640000.0, 6494.488490527602, 982.0, 15106.986883848309, 31881444.0)

# %%
actor_1_fb_likes.describe()
# Out:
# count      4909.000000
# mean       6494.488491
# std       15106.986884
# min           0.000000
# 25%         607.000000
# 50%         982.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
actor_1_fb_likes.quantile(.2)
#Return values at the given quantile over requested axis.
#Parameters
# q float or array-like, default 0.5 (50% quantile)
# Value between 0 <= q <= 1, the quantile(s) to compute.
# Out:
# 510.0

# %%
actor_1_fb_likes.quantile([.1, .2, .3, .4, .5, .6, .7, .8, .9])
# Out:
# 0.1      240.0
# 0.2      510.0
# 0.3      694.0
# 0.4      854.0
# 0.5      982.0
# 0.6     1000.0
# 0.7     8000.0
# 0.8    13000.0
# 0.9    18000.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
director.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
director.isnull().count() # does not count the only null values proerly shows 4916 as result so we need to use Value_counts

# %%
director.isnull().value_counts() # here its shows that 4814 values are not null remining 102 are nulls
# Out:
# False    4814
# True      102
# Name: director_name, dtype: int64

# %%
actor_1_fb_likes.isnull().value_counts() # 7 values are null
# Out:
# False    4909
# True        7
# Name: actor_1_facebook_likes, dtype: int64

# %%
actors_1_fb_likes_filled = actor_1_fb_likes.fillna(0) # filling the nulls values with 0

# %%
actors_1_fb_likes_filled.isnull().value_counts() # checking again and now no null values exist
# Out:
# False    4916
# Name: actor_1_facebook_likes, dtype: int64

# %%
actors_1_fb_likes_dropped = actor_1_fb_likes.dropna()
actors_1_fb_likes_dropped.size #
#Remove missing values.
#See the User Guide for more on which values are considered missing, and how to work with missing data.
# Out:
# 4909

# %%
actors_1_fb_likes_dropped.head()
# Out:
# 0     1000.0
# 1    40000.0
# 2    11000.0
# 3    27000.0
# 4      131.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
actors_1_fb_likes_dropped.describe()
# Out:
# count      4909.000000
# mean       6494.488491
# std       15106.986884
# min           0.000000
# 25%         607.000000
# 50%         982.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %% [markdown]
# #### working with operators on a series

# %%
5+9
# Out:
# 14

# %%
4**2
# Out:
# 16

# %%
a=10

# %%
a
# Out:
# 10

# %%
5<=9
# Out:
# True

# %%
'abcd' + 'fg'
# Out:
# 'abcdfg'

# %%
not(5<=9)
# Out:
# False

# %%
7 in [1,2,3]
# Out:
# False

# %%
[1,2,3] - 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/2932045491.py in <module>
# ----> 1 [1,2,3] - [3,2,1]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
a = set([1,2,3])
a
# Out:
# {1, 2, 3}

# %%
movie = pd.read_csv('data/movie.csv')
imdb_score = movie ['imdb_score']
imdb_score
# Out:
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
#        ...
# 4911    7.7
# 4912    7.5
# 4913    6.3
# 4914    6.3
# 4915    6.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score+1
# Out:
# 0       8.9
# 1       8.1
# 2       7.8
# 3       9.5
# 4       8.1
#        ...
# 4911    8.7
# 4912    8.5
# 4913    7.3
# 4914    7.3
# 4915    7.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score * 2.5
# Out:
# 0       19.75
# 1       17.75
# 2       17.00
# 3       21.25
# 4       17.75
#         ...
# 4911    19.25
# 4912    18.75
# 4913    15.75
# 4914    15.75
# 4915    16.50
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score //7
# Out:
# 0       1.0
# 1       1.0
# 2       0.0
# 3       1.0
# 4       1.0
#        ...
# 4911    1.0
# 4912    1.0
# 4913    0.0
# 4914    0.0
# 4915    0.0
# Name: imdb_score, Length: 4916, dtype: float64

# %%
director = movie['director_name']

# %%
director
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
er = director == 'James Cameron'

# %%
er
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
er.value_counts()
# Out:
# False    4909
# True        7
# Name: director_name, dtype: int64

# %% [markdown]
# #### Changing series methods together

# %%
movie = pd.read_csv('data/movie.csv')
actor_1_fb_likes = movie['actor_1_facebook_likes']
director = movie['director_name']

# %%
movie.shape # displays rows and columns of a dataset
# Out:
# (4916, 28)

# %%
movie.count() #displays the counts of each column in the dataset excluding null values
# Out:
# color                        4897
# director_name                4814
# num_critic_for_reviews       4867
# duration                     4901
# director_facebook_likes      4814
# actor_3_facebook_likes       4893
# actor_2_name                 4903
# actor_1_facebook_likes       4909
# gross                        4054
# genres                       4916
# actor_1_name                 4909
# movie_title                  4916
# num_voted_users              4916
# cast_total_facebook_likes    4916
# actor_3_name                 4893
# facenumber_in_poster         4903
# plot_keywords                4764
# movie_imdb_link              4916
# num_user_for_reviews         4895
# language                     4904
# country                      4911
# content_rating               4616
# budget                       4432
# title_year                   4810
# actor_2_facebook_likes       4903
# imdb_score                   4916
# aspect_ratio                 4590
# ...

# %%
director.value_counts().tail() # count of last five unique director values
# Out:
# John Putch         1
# Luca Guadagnino    1
# Sam Fell           1
# Dan Fogelman       1
# Daniel Hsia        1
# Name: director_name, dtype: int64

# %%
director.isnull().sum() # sum of all null values in a director column
# Out:
# 102

# %%
actor_1_fb_likes = movie['actor_1_facebook_likes']

# %%
actor_1_fb_likes.dtype
# Out:
# dtype('float64')

# %%
actor_1_fb_likes.fillna(0).astype(int).tail().sum()
# Out:
# 2510

# %% [markdown]
# ## Making Index meaningful

# %%
movie = pd.read_csv('data\movie.csv')
movie2 = movie.set_index(['movie_title','director_name'])
movie2
# Out:
#                                                               color  \
# movie_title                                director_name
# Avatar                                     James Cameron      Color
# Pirates of the Caribbean: At World's End   Gore Verbinski     Color
# Spectre                                    Sam Mendes         Color
# The Dark Knight Rises                      Christopher Nolan  Color
# Star Wars: Episode VII - The Force Awakens Doug Walker          NaN
# ...                                                             ...
# Signed Sealed Delivered                    Scott Smith        Color
# The Following                              NaN                Color
# A Plague So Pleasant                       Benjamin Roberds   Color
# Shanghai Calling                           Daniel Hsia        Color
# My Date with Drew                          Jon Gunn           Color
#
#                                                               num_critic_for_reviews  \
# ...

# %%
movie = pd.read_csv('data\movie.csv', index_col = 'movie_title')
movie
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# ...

# %%
movie2.reset_index()
# Out:
#                                      movie_title      director_name  color  \
# 0                                         Avatar      James Cameron  Color
# 1       Pirates of the Caribbean: At World's End     Gore Verbinski  Color
# 2                                        Spectre         Sam Mendes  Color
# 3                          The Dark Knight Rises  Christopher Nolan  Color
# 4     Star Wars: Episode VII - The Force Awakens        Doug Walker    NaN
# ...                                          ...                ...    ...
# 4911                     Signed Sealed Delivered        Scott Smith  Color
# 4912                               The Following                NaN  Color
# 4913                        A Plague So Pleasant   Benjamin Roberds  Color
# 4914                            Shanghai Calling        Daniel Hsia  Color
# 4915                           My Date with Drew           Jon Gunn  Color
#
#       num_critic_for_reviews  duration  director_facebook_likes  \
# ...

# %% [markdown]
# ### Renaming row and column names

# %%
movie = pd.read_csv('data/movie.csv', index_col = 'movie_title')

# %%
idx_rename = {'Avatar': 'Ratava','Spectre': 'Ertceps'}
col_name = {'director_name': 'Director Name', 'num_critic_for_reviews':'Critical Reviews'}

# %%
movie.rename(index=idx_rename, columns = col_name).head()
# Out:
#                                             color      Director Name  \
# movie_title
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# movie_title
# Ratava                                                 723.0     178.0
# Pirates of the Caribbean: At World's End               302.0     169.0
# Ertceps                                                602.0     148.0
# The Dark Knight Rises                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# ...

# %%
movie = pd.read_csv('data/movie.csv', index_col='movie_title')
index = movie.index
index
# Out:
# Index(['Avatar', 'Pirates of the Caribbean: At World's End', 'Spectre',
#        'The Dark Knight Rises', 'Star Wars: Episode VII - The Force Awakens',
#        'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron',
#        'Harry Potter and the Half-Blood Prince',
#        ...
#        'Primer', 'Cavite', 'El Mariachi', 'The Mongol King', 'Newlyweds',
#        'Signed Sealed Delivered', 'The Following', 'A Plague So Pleasant',
#        'Shanghai Calling', 'My Date with Drew'],
#       dtype='object', name='movie_title', length=4916)

# %%
columns = movie.columns
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
index_list = index.tolist()
index_list
# Out:
# ['Avatar',
#  "Pirates of the Caribbean: At World's End",
#  'Spectre',
#  'The Dark Knight Rises',
#  'Star Wars: Episode VII - The Force Awakens',
#  'John Carter',
#  'Spider-Man 3',
#  'Tangled',
#  'Avengers: Age of Ultron',
#  'Harry Potter and the Half-Blood Prince',
#  'Batman v Superman: Dawn of Justice',
#  'Superman Returns',
#  'Quantum of Solace',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Lone Ranger',
#  'Man of Steel',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Avengers',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Men in Black 3',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Amazing Spider-Man',
#  'Robin Hood',
#  'The Hobbit: The Desolation of Smaug',
#  'The Golden Compass',
#  'King Kong',
#  'Titanic',
#  'Captain America: Civil War',
#  'Battleship',
#  'Jurassic World',
#  'Skyfall',
#  'Spider-Man 2',
#  'Iron Man 3',
#  'Alice in Wonderland',
#  'X-Men: The Last Stand',
#  'Monsters University',
# ...

# %%
column_list = columns.tolist()
column_list
# Out:
# ['color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %%
index_list[0]
# Out:
# 'Avatar'

# %%
index_list[0]='Ratava'

# %%
index_list[0]
# Out:
# 'Ratava'

# %%
index_list[1] = 'Ertceps'

# %%
index_list[1]
# Out:
# 'Ertceps'

# %%
column_list[0]
# Out:
# 'color'

# %%
index_list[0] = 'Colour'

# %%
index_list[0]
# Out:
# 'Colour'

# %%
column_list[2]
# Out:
# 'num_critic_for_reviews'

# %%
column_list[2] = 'Critical Reviews'

# %%
column_list[2]
# Out:
# 'Critical Reviews'

# %%
print(index_list)
# Out:
# ['Colour', 'Ertceps', 'Spectre', 'The Dark Knight Rises', 'Star Wars: Episode VII - The Force Awakens', 'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'Superman Returns', 'Quantum of Solace', "Pirates of the Caribbean: Dead Man's Chest", 'The Lone Ranger', 'Man of Steel', 'The Chronicles of Narnia: Prince Caspian', 'The Avengers', 'Pirates of the Caribbean: On Stranger Tides', 'Men in Black 3', 'The Hobbit: The Battle of the Five Armies', 'The Amazing Spider-Man', 'Robin Hood', 'The Hobbit: The Desolation of Smaug', 'The Golden Compass', 'King Kong', 'Titanic', 'Captain America: Civil War', 'Battleship', 'Jurassic World', 'Skyfall', 'Spider-Man 2', 'Iron Man 3', 'Alice in Wonderland', 'X-Men: The Last Stand', 'Monsters University', 'Transformers: Revenge of the Fallen', 'Transformers: Age of Extinction', 'Oz the Great and Powerful', 'The Amazing Spider-Man 2', 'TRON: Legacy', 'Cars 2
# ...

# %%
print(column_list)
# Out:
# ['color', 'director_name', 'Critical Reviews', 'duration', 'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name', 'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name', 'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link', 'num_user_for_reviews', 'language', 'country', 'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score', 'aspect_ratio', 'movie_facebook_likes']

# %%
movie.index = index_list

# %%
movie.index
# Out:
# Index(['Colour', 'Ertceps', 'Spectre', 'The Dark Knight Rises',
#        'Star Wars: Episode VII - The Force Awakens', 'John Carter',
#        'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron',
#        'Harry Potter and the Half-Blood Prince',
#        ...
#        'Primer', 'Cavite', 'El Mariachi', 'The Mongol King', 'Newlyweds',
#        'Signed Sealed Delivered', 'The Following', 'A Plague So Pleasant',
#        'Shanghai Calling', 'My Date with Drew'],
#       dtype='object', length=4916)

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movie.columns = column_list

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'Critical Reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movie.head()
# Out:
#                                             color      director_name  \
# Colour                                      Color      James Cameron
# Ertceps                                     Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# Colour                                                 723.0     178.0
# Ertceps                                                302.0     169.0
# Spectre                                                602.0     148.0
# The Dark Knight Rises                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# ...

# %% [markdown]
# ### Creating and deleting columns

# %%
movie = pd.read_csv('data/movie.csv')

# %%
movie['qwert'] = round(movie.imdb_score,0)
movie.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
#
#   language country  content_rating       budget title_year  \
# 0  English     USA           PG-13  237000000.0     2009.0
# 1  English     USA           PG-13  300000000.0     2007.0
#
#    actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes qwert
# 0                   936.0        7.9         1.78                 33000   8.0
# ...

# %%
movie[['actor_1_facebook_likes', 'actor_2_facebook_likes']].head() # displays the selected columns
# Out:
#    actor_1_facebook_likes  actor_2_facebook_likes
# 0                  1000.0                   936.0
# 1                 40000.0                  5000.0
# 2                 11000.0                   393.0
# 3                 27000.0                 23000.0
# 4                   131.0                    12.0

# %%
movie['actor_director_facebook_likes'] = (movie['actor_1_facebook_likes']+
                                             movie['actor_2_facebook_likes']+
                                             movie['actor_3_facebook_likes']+
                                             movie['director_facebook_likes'])

# %%
movie['actor_director_facebook_likes']
# Out:
# 0        2791.0
# 1       46563.0
# 2       11554.0
# 3       95000.0
# 4           NaN
#          ...
# 4911     1427.0
# 4912        NaN
# 4913        0.0
# 4914     2154.0
# 4915      141.0
# Name: actor_director_facebook_likes, Length: 4916, dtype: float64

# %%
movie['actor_director_facebook_likes'].isnull().sum()
# Out:
# 122

# %%
movie['actor_director_facebook_likes'] = movie['actor_director_facebook_likes'].fillna(0)

# %%
movie.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movie['cast_total_facebook_likes'] = (movie['cast_total_facebook_likes']>=
                                        movie['actor_director_facebook_likes'])

# %%
(movie['cast_total_facebook_likes'].sum()/movie['cast_total_facebook_likes'].count())*100
# Out:
# 80.81773799837266

# %%
movie = movie.drop('actor_director_facebook_likes') # reuire axis to declare check next cell
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/1629359558.py in <module>
# ----> 1 movie = movie.drop('actor_director_facebook_likes')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
movie = movie.drop('actor_director_facebook_likes', axis= 'columns')

# %%
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...
